# %%
pip install -i https://test.pypi.org/simple/ osny-imagem-processing
# Out:
# Looking in indexes: https://test.pypi.org/simple/
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from osny_imagem_processing.utils import io, plot
from osny_imagem_processing.processing import combination, transformation

# %%
image2 = io.read_image("C:/Users/osnyn/OneDrive/Imagens/eu.jpg")
image1 = io.read_image("C:/Users/osnyn/OneDrive/Imagens/Cauaa.jpg")

# %%
plot.plot_image(image1)
plot.plot_image(image2)

# %%
result_image = combination.transfer_histogram(image1,image2)
plot.plot_result(image1,image2,result_image)
